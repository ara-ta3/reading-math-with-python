# %% [markdown]
# # データをグラフで可視化する

# %%
simplelist = [1,2,3]

# %%
simplelist[0]
# Out:
# 1

# %%
emptylist = []

# %%
emptylist
# Out:
# []

# %%
emptylist.append(1)

# %%
emptylist
# Out:
# [1]

# %%
simpletuple = (1,2,3)

# %%
simpletuple[0]
# Out:
# 1

# %%
for idx, item in enumerate(simplelist):
    print (idx, item)
# Out:
# 0 1
# 1 2
# 2 3

# %% [markdown]
# ```
# from pylab import plot,show
# ```
# ってなってたけど、matplotlib.pylabじゃないと動かなかった

# %%
x = [1,2,3]
y = [2,4,6]

from matplotlib.pylab import plot, show
# %matplotlib inline
plot(x, y)
show()

# %%
plot(x,y, marker='o')

# %%
nyc_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]
plot(nyc_temp, marker='o')

# %%
years = range(2000,2013)
plot(years, nyc_temp, marker='o')

# %%
nyc_temp_2000 = [31.3, 37.3, 47.2, 51.0, 63.5, 71.3, 72.3, 72.7, 66.0, 57.0, 45.3, 31.1]
nyc_temp_2006 = [40.9, 35.7, 43.1, 55.7, 63.1, 71.0, 77.9, 75.8, 66.6, 56.2, 51.9, 43.6]
nyc_temp_2012 = [37.3, 40.9, 50.9, 54.8, 65.1, 71.0, 78.8, 76.7, 68.8, 58.0, 43.9, 41.5]

months = range(1,13)
plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)

# %%
from matplotlib.pylab import legend
legend([2000,2006,2012])

# %%
from matplotlib import pylab

pylab.plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)
pylab.legend([2000,2006,2012])
pylab.show()

# %%
from matplotlib.pylab import plot, show, title, xlabel, ylabel, legend
plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)
title('Average monthly temperature in NYC')
xlabel('Month')
ylabel('Temperature')
legend([2000, 2006, 2012])

# %%
plot(nyc_temp, marker='o')
from matplotlib.pylab import axis
axis(ymin=0)
# Out:
# (0.0, 12.0, 0, 57.5)

# %%
from matplotlib import pyplot

def create_graph():
    x = [1,2,3]
    y = [2,4,6]
    pyplot.plot(x, y)
    pyplot.show()

create_graph()

# %%
plot(x,y)

# %%
from matplotlib.pylab import savefig
savefig("mygraph.png")

# %%
import matplotlib.pyplot as plt

def draw_graph(x, y):
    plt.plot(x, y, marker='o')
    plt.xlabel('Distance in meters')
    plt.ylabel('Gravitational force in newtons')
    plt.title('Gravitational force and distance')
    plt.show()

def generate_F_r():
    r = range(100,1001, 50)
    F = []
    G = 6.674 * (10**-11)
    m1 = 0.5
    m2 = 1.5
    for dist in r:
        force = G * (m1*m2) / (dist ** 2)
        F.append(force)
    draw_graph(r, F)

generate_F_r()

# %%
def frange(start, final, increment):
    numbers = []
    while start < final:
        numbers.append(start)
        start = start + increment
    return numbers

from matplotlib import pyplot as plt
import math

def draw_graph(x,y):
    plt.plot(x,y)
    plt.xlabel('x-coordinate')
    plt.ylabel('y-coordinate')
    plt.tilte('Projectile motion of a ball')

def draw_trajectory(u, theta):
    theta = math.radians(theta)
    g = 9.8
    # Time of flight
    t_flight = 2*u*math.sin(theta)/g
    # find time intervals
    intervals = frange(0, t_flight, 0.001) # list of x and y coordinates
    x = []
    y = []
    for t in intervals:
        x.append(u*math.cos(theta)*t)
        y.append(u*math.sin(theta)*t - 0.5*g*t*t) 
    draw_graph(x, y)

try:
    u = float(input('Enter the initial velocity (m/s): '))
    theta = float(input('Enter the angle of projection (degrees): '))
except ValueError:
    print('You entered an invalid input')
else:
    draw_trajectory(u, theta) 
    plt.show()
# Out:
# Enter the initial velocity (m/s): 10
# Enter the angle of projection (degrees): 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-c5bd59d7e485> in <module>()
#      35     print('You entered an invalid input')
#      36 else:
# ---> 37     draw_trajectory(u, theta)
#      38     plt.show()
#
# <ipython-input-32-c5bd59d7e485> in draw_trajectory(u, theta)
#      27         x.append(u*math.cos(theta)*t)
#      28         y.append(u*math.sin(theta)*t - 0.5*g*t*t)
# ---> 29     draw_graph(x, y)
#      30
#      31 try:
#
# <ipython-input-32-c5bd59d7e485> in draw_graph(x, y)
#      13     plt.xlabel('x-coordinate')
#      14     plt.ylabel('y-coordinate')
# ---> 15     plt.tilte('Projectile motion of a ball')
#      16
#      17 def draw_trajectory(u, theta):
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tilte'

# %%
from matplotlib import pyplot as plt

xs = range(-10, 10)
ys = []
for x in xs:
    y = x ** 2 + 2 * x + 1
    ys.append(y)
plt.plot(xs, ys)
plt.title("問題2-2")
plt.show()

# %%
def fibo(n):
    if n == 1:
        return [1]
    if n == 2:
        return [1,1]
    a = 1
    b = 1
    series = [a, b]
    for i in range(n):
        c = a + b
        series.append(c)
        a = b
        b = c
    return series

def create_ratio(n):
    fibs = fibo(n)
    idx = 0
    rs = []
    while idx < len(fibs) - 1:
        a = fibs[idx]
        b = fibs[idx + 1]
        rs.append(b / a)
        idx +=1
    return rs


from matplotlib import pyplot as plt

x = list(range(1, 102))
y = create_ratio(100)
plt.plot(x, y)
plt.title("Q2-5")
plt.show()
