# %% [markdown]
# # 6章 幾何図形とフラクタルを描画する

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y = [1,2,3]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y = [1,2,3]
fig = plt.figure()
ax = plt.axes()
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt

c = plt.Circle((0, 0), radius= 0.5)

ax = plt.gca()
# ax.set_aspect('equal')
ax.add_patch(c)
plt.axis('scaled')
plt.show()

# %%
# %matplotlib nbagg
# @see http://qiita.com/Tatejimaru137/items/6083e2e3a4e618da6274

# %%
import matplotlib.pyplot as plt
from matplotlib import animation

def update_radius(i, circle):
    circle.radius = i * 0.5
    return circle

fig = plt.gcf()
ax = plt.axes(xlim = (-10, 10), ylim = (-10, 10))
ax.set_aspect('equal')

c = plt.Circle((0, 0), radius= 5)

ax.add_patch(c)

anim = animation.FuncAnimation(fig, update_radius, fargs = (c,), frames = 30, interval =50)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import math

g = 9.8

def get_intervals(u, theta):
    t_flight = 2 * u * math.sin(theta)/ g
    intervals = []
    start = 0
    interval= 0.005
    while start < t_flight:
        intervals.append(start)
        start = start + interval
    return intervals

def update_position(i, circle, intervals, u, theta):
    t = intervals[i]
    x = u * math.cos(theta) * t
    y = u * math.sin(theta) * t - 0.5 * g * t * t
    circle.center = x,y
    return circle

def create_animation(u, theta):
    intervals = get_intervals(u, theta)
    xmin = 0
    xmax = u * math.cos(theta) * intervals[-1]
    ymin = 0
    t_max = u * math.sin(theta)/g
    ymax = u * math.sin(theta)*t_max - 0.5 * g * t_max**2
    fig = plt.gcf()
    ax = plt.axes(xlim = (-xmax, xmax), ylim=(ymin, ymax))
    
    c = plt.Circle((xmin, ymin), 1.0)
    ax.add_patch(c)
    anim = animation.FuncAnimation(fig, update_position,
                                  fargs = (c, intervals, u, theta),
                                  frames = len(intervals), interval = 1,
                                  repeat = False)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.show()

    
if __name__ == "__main__":
    u = 10
    theta = math.radians(60)
    create_animation(u, theta)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# 図書くの楽しくないからパスしようかなという気持ち
